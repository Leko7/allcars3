# %%
import pandas as pd

file_path = "audi_cars.jsonl"
df = pd.read_json(file_path, lines=True)
df.head()
# Out:
#   What is the body type, Audi A3 allstreet (8Y, facelift 2024)?  \
# 0                        Crossover, 5 Doors, 5 Seats
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the fuel economy, Audi A3 allstreet (8Y, facelift 2024) 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                  0.3-0.4  l/100 km
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How ECO is the car, Audi A3 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                       7-8  g/km CO
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the range of pure electric driving, 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                        128-139  km
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is electricity consumption, Audi A3 allstreet (8Y, facelift 2024) 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                   15-16 kWh/100 km
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How fast is the car, 2024 A3 allstreet (8Y, facelift 2024) 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                              225 km/h | 139.81 mph
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How much power, Audi A3 Crossover 2024 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                   204  Hp, 350  Nm
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the engine size, Audi A3 Crossover 2024 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                              1.5 l
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many cylinders, 2024 Audi 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0                                          4, Inline
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the drivetrain, Audi A3 allstreet (8Y, facelift 2024) Crossover 2024 40 TFSI e (204 Hp) Plug-in Hybrid S tronic?  \
# 0  Front wheel drive. PHEV (Plug-in Hybrid Electr...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   What is the fuel economy, Audi Q3 Sportback (F3) 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How ECO is the car, Audi Q3 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How fast is the car, 2019 Q3 Sportback (F3) 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How much power, Audi Q3 Coupe, SUV 2019 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the engine size, Audi Q3 Coupe, SUV 2019 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many cylinders, 2019 Audi 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the drivetrain, Audi Q3 Sportback (F3) Coupe, SUV 2019 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the curb weight, 2019 Audi Q3 Sportback (F3) 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the gross weight, 2019 Audi Q3 Sportback (F3) 45 TFSI (230 Hp) quattro S tronic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many gears, What type is the gearbox, 2019 Audi Q3 Sportback (F3) 45 TFSI (230 Hp) quattro S tronic?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 5210 columns]

# %%
import pandas as pd

file_path = "audi_cars_new.jsonl"
df = pd.read_json(file_path, lines=True)
df.head()
# Out:
#                                   body_type       fuel_economy           eco  \
# 0               Crossover, 5 Doors, 5 Seats  0.3-0.4  l/100 km  7-8  g/km CO
# 1                     SUV, 5 Doors, 5 Seats                NaN           NaN
# 2  Station wagon (estate), 5 Doors, 5 Seats                NaN           NaN
# 3                Liftback, 5 Doors, 5 Seats                NaN           NaN
# 4  Station wagon (estate), 5 Doors, 5 Seats                NaN           NaN
#
#   electric_driving_range electricity_consumption                  speed  \
# 0            128-139  km        15-16 kWh/100 km  225 km/h | 139.81 mph
# 1            476-483  km    24.7-25.4 kWh/100 km  200 km/h | 124.27 mph
# 2            605-685  km    15.5-17.5 kWh/100 km  210 km/h | 130.49 mph
# 3            644-716  km    14.7-16.5 kWh/100 km  210 km/h | 130.49 mph
# 4            520-598  km    14.4-16.6 kWh/100 km  210 km/h | 130.49 mph
#
#               power engine_size n_cylinders  \
# 0  204  Hp, 350  Nm       1.5 l   4, Inline
# 1  408  Hp, 664  Nm         NaN         NaN
# 2           462  Hp         NaN         NaN
# 3           462  Hp         NaN         NaN
# 4  326  Hp, 435  Nm         NaN         NaN
#
#                                           drivetrain  ...  \
# 0  Front wheel drive. PHEV (Plug-in Hybrid Electr...  ...
# 1  All wheel drive (4x4). BEV (Electric Vehicle)....  ...
# 2  All wheel drive (4x4). BEV (Electric Vehicle)....  ...
# 3  All wheel drive (4x4). BEV (Electric Vehicle)....  ...
# 4  Rear wheel drive. BEV (Electric Vehicle). One ...  ...
#
#   Combined fuel consumption (WLTP) (CNG)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Fuel consumption (economy) - urban (CNG) (NEDC)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Fuel consumption (economy) - extra urban (CNG) (NEDC)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Fuel consumption (economy) - combined (CNG) (NEDC) CNG cylinder capacity  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#   Electric motor model/code Maximum revolutions of the electric motor  \
# 0                       NaN                                       NaN
# 1                       NaN                                       NaN
# 2                       NaN                                       NaN
# 3                       NaN                                       NaN
# 4                       NaN                                       NaN
#
#   All-electric range (NEDC) All-electric range (NEDC, WLTP equivalent)  \
# 0                       NaN                                        NaN
# 1                       NaN                                        NaN
# 2                       NaN                                        NaN
# 3                       NaN                                        NaN
# 4                       NaN                                        NaN
#
#   All-electric range
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 154 columns]

# %%
cols = df.columns.tolist()
i=0

# %%
i+=10
df[cols[i:i+10]]
# Out:
#     All-electric range (WLTP) Average Energy consumption (WLTP)  \
# 0                  128-139 km                  15-16 kWh/100 km
# 1                  476-483 km              24.7-25.4 kWh/100 km
# 2                  605-685 km              15.5-17.5 kWh/100 km
# 3                  644-716 km              14.7-16.5 kWh/100 km
# 4                  520-598 km              14.4-16.6 kWh/100 km
# ..                        ...                               ...
# 499                       NaN                               NaN
# 500                       NaN                               NaN
# 501                       NaN                               NaN
# 502                       NaN                               NaN
# 503                       NaN                               NaN
#
#     Max speed (electric)  Charging ports  Electric motor 1  \
# 0               140 km/h  Log in to see.               NaN
# 1                    NaN  Log in to see.               NaN
# 2                    NaN  Log in to see.               NaN
# 3                    NaN  Log in to see.               NaN
# 4                    NaN  Log in to see.               NaN
# ..                   ...             ...               ...
# 499                  NaN             NaN               NaN
# 500                  NaN             NaN               NaN
# 501                  NaN             NaN               NaN
# 502                  NaN             NaN               NaN
# 503                  NaN             NaN               NaN
#
#     Electric motor power Electric motor Torque  \
# 0                 116 Hp                330 Nm
# 1                 184 Hp                309 Nm
# 2                    NaN                275 Nm
# 3                    NaN                275 Nm
# 4                 326 Hp                435 Nm
# ..                   ...                   ...
# 499                  NaN                   NaN
# 500                  NaN                   NaN
# 501                  NaN                   NaN
# 502                  NaN                   NaN
# 503                  NaN                   NaN
#
#                                Electric motor location Electric motor type  \
# 0    Between the combustion engine and the transmis...         Synchronous
# 1                               Front axle, Transverse        Asynchronous
# 2                               Front axle, Transverse        Asynchronous
# 3                               Front axle, Transverse        Asynchronous
# 4                                Rear axle, Transverse         Synchronous
# ..                                                 ...                 ...
# 499                                                NaN                 NaN
# 500                                                NaN                 NaN
# 501                                                NaN                 NaN
# 502                                                NaN                 NaN
# 503                                                NaN                 NaN
#
#     System power
# 0         204 Hp
# 1         408 Hp
# 2         462 Hp
# 3         462 Hp
# 4         326 Hp
# ..           ...
# 499          NaN
# 500          NaN
# 501          NaN
# 502          NaN
# 503          NaN
#
# [504 rows x 10 columns]

# %%
import pandas as pd

file_path = "away_abarth_cars.jsonl"
df = pd.read_json(file_path, lines=True)
df.head()
# Out:
#   What is the body type, Aiways U6?  \
# 0      Coupe, SUV, 5 Doors, 5 Seats
# 1                               NaN
# 2                               NaN
# 3      Coupe, SUV, 5 Doors, 5 Seats
# 4                               NaN
#
#   What is the range of pure electric driving, PRIME 63 kWh (218 Hp) Electric?  \
# 0                                            405  km
# 1                                                NaN
# 2                                                NaN
# 3                                            405  km
# 4                                                NaN
#
#   What is electricity consumption, Aiways U6 PRIME 63 kWh (218 Hp) Electric?  \
# 0                                      16 kWh/100 km
# 1                                                NaN
# 2                                                NaN
# 3                                      16 kWh/100 km
# 4                                                NaN
#
#   How fast is the car, 2022 U6 PRIME 63 kWh (218 Hp) Electric?  \
# 0                               160 km/h | 99.42 mph
# 1                                                NaN
# 2                                                NaN
# 3                               160 km/h | 99.42 mph
# 4                                                NaN
#
#   How much power, Aiways U6 Coupe, SUV 2022 PRIME 63 kWh (218 Hp) Electric?  \
# 0                                   218  Hp, 315  Nm
# 1                                                NaN
# 2                                                NaN
# 3                                   218  Hp, 315  Nm
# 4                                                NaN
#
#   What is the drivetrain, Aiways U6 Coupe, SUV 2022 PRIME 63 kWh (218 Hp) Electric?  \
# 0  Front wheel drive. BEV (Electric Vehicle). One...
# 1                                                NaN
# 2                                                NaN
# 3  Front wheel drive. BEV (Electric Vehicle). One...
# 4                                                NaN
#
#   How long is this vehicle, 2022 Aiways U6 Coupe, SUV?  \
# 0                                           4805  mm
# 1                                                NaN
# 2                                                NaN
# 3                                           4805  mm
# 4                                                NaN
#
#   How wide is the vehicle, 2022 Aiways U6 Coupe, SUV?  \
# 0                                           1880  mm
# 1                                                NaN
# 2                                                NaN
# 3                                           1880  mm
# 4                                                NaN
#
#   What is the curb weight, 2022 Aiways U6 PRIME 63 kWh (218 Hp) Electric?  \
# 0                                           1790  kg
# 1                                                NaN
# 2                                                NaN
# 3                                           1790  kg
# 4                                                NaN
#
#   How much trunk (boot) space, 2022 Aiways U6 Coupe, SUV?  ...  \
# 0                                      472 - 1260  l       ...
# 1                                                NaN       ...
# 2                                                NaN       ...
# 3                                      472 - 1260  l       ...
# 4                                                NaN       ...
#
#   What is the curb weight, 2016 Abarth 595 (facelift 2016) Competizione 1.4 T-Jet (180 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many gears, What type is the gearbox, 2016 Abarth 595 (facelift 2016) Competizione 1.4 T-Jet (180 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the fuel economy, Abarth 124 Spider 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How fast is the car, 2016 124 Spider 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How much power, Abarth 124 Spider Cabriolet 2016 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the engine size, Abarth 124 Spider Cabriolet 2016 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many cylinders, 2016 Abarth 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is the drivetrain, Abarth 124 Spider Cabriolet 2016 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    What is the curb weight, 2016 Abarth 124 Spider 1.4 MultiAir (170 Hp) Automatic?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    How many gears, What type is the gearbox, 2016 Abarth 124 Spider 1.4 MultiAir (170 Hp) Automatic?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 749 columns]

# %%
file_path = "away_abarth_cars_new.jsonl"
df = pd.read_json(file_path, lines=True)
df.head()
# Out:
#                     q_body_type q_electric_driving_range  \
# 0  Coupe, SUV, 5 Doors, 5 Seats                  405  km
# 1         SUV, 5 Doors, 5 Seats                  400  km
# 2         SUV, 5 Doors, 5 Seats                  410  km
# 3  Coupe, SUV, 5 Doors, 5 Seats                  405  km
# 4         SUV, 5 Doors, 5 Seats                  400  km
#
#   q_electricity_consumption               q_speed           q_power  \
# 0             16 kWh/100 km  160 km/h | 99.42 mph  218  Hp, 315  Nm
# 1           17.0 kWh/100 km  0-100 km/h: 7.8  sec           204  Hp
# 2           16.6 kWh/100 km  0-100 km/h: 7.5  sec           204  Hp
# 3             16 kWh/100 km  160 km/h | 99.42 mph  218  Hp, 315  Nm
# 4           17.0 kWh/100 km  0-100 km/h: 7.8  sec           204  Hp
#
#                                         q_drivetrain  q_length   q_width  \
# 0  Front wheel drive. BEV (Electric Vehicle). One...  4805  mm  1880  mm
# 1  Front wheel drive. BEV (Electric Vehicle). One...  4680  mm  1865  mm
# 2  Front wheel drive. BEV (Electric Vehicle). One...  4680  mm  1865  mm
# 3  Front wheel drive. BEV (Electric Vehicle). One...  4805  mm  1880  mm
# 4  Front wheel drive. BEV (Electric Vehicle). One...  4680  mm  1865  mm
#
#   q_curb_weight q_trunk_boot_space  ... Max. roof load  \
# 0      1790  kg      472 - 1260  l  ...            NaN
# 1      1770  kg      432 - 1555  l  ...            NaN
# 2      1720  kg      432 - 1555  l  ...            NaN
# 3      1790  kg      472 - 1260  l  ...            NaN
# 4      1770  kg      432 - 1555  l  ...            NaN
#
#   Permitted trailer load with brakes (12%)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Permitted trailer load without brakes Permitted towbar download  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
#
#   Fuel consumption (economy) - combined Fuel consumption at Low speed (WLTP)  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   Fuel consumption at Medium speed (WLTP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Fuel consumption at high speed (WLTP)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Fuel consumption at very high speed (WLTP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Combined fuel consumption (WLTP)
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 125 columns]

# %%
df.shape
# Out:
# (69, 125)

# %%
cols = df.columns.tolist()
i=0

# %%
i+=10
df[cols[i:i+10]]
# Out:
#             Engine aspiration Valvetrain Engine oil capacity  \
# 0                         NaN        NaN                 NaN
# 1                         NaN        NaN                 NaN
# 2                         NaN        NaN                 NaN
# 3                         NaN        NaN                 NaN
# 4                         NaN        NaN                 NaN
# ..                        ...        ...                 ...
# 64  Turbocharger, Intercooler        NaN               2.9 l
# 65  Turbocharger, Intercooler        NaN               2.9 l
# 66  Turbocharger, Intercooler        NaN               2.9 l
# 67  Turbocharger, Intercooler        NaN               2.9 l
# 68  Turbocharger, Intercooler        NaN               3.8 l
#
#    Engine oil specification Max. weight Max load Fuel tank capacity  \
# 0                       NaN         NaN      NaN                NaN
# 1                       NaN         NaN      NaN                NaN
# 2                       NaN         NaN      NaN                NaN
# 3                       NaN         NaN      NaN                NaN
# 4                       NaN         NaN      NaN                NaN
# ..                      ...         ...      ...                ...
# 64           Log in to see.         NaN      NaN               35 l
# 65           Log in to see.         NaN      NaN               35 l
# 66           Log in to see.         NaN      NaN               35 l
# 67           Log in to see.         NaN      NaN               35 l
# 68           Log in to see.         NaN      NaN               45 l
#
#    Width including mirrors Front track Rear (Back) track
# 0                      NaN         NaN               NaN
# 1                      NaN         NaN               NaN
# 2                      NaN         NaN               NaN
# 3                      NaN         NaN               NaN
# 4                      NaN         NaN               NaN
# ..                     ...         ...               ...
# 64                 1893 mm     1415 mm           1408 mm
# 65                 1893 mm     1415 mm           1408 mm
# 66                 1893 mm     1415 mm           1408 mm
# 67                 1893 mm     1415 mm           1408 mm
# 68                     NaN     1496 mm           1503 mm
#
# [69 rows x 10 columns]

# %%
i=0

# %%
i += 10
df.iloc[[65]][cols[i:i+10]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [65]

# %%
data['abarth']
# Out:
# 'https://www.auto-data.net/en/results?brand=200&model=0&power1=&power2=#google_vignette'
